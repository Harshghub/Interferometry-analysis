# %%
a =  [1,4,3]
b = ['a','b','c']

c = zip(a,b)

# %%
list(sorted(c))
# Out:
# []

# %%
(sorted(c))
# Out:
# [(1, 'a'), (3, 'c'), (4, 'b')]

# %%
zip(*c)

# %%
*c
# Out:
#   Cell In[29], line 1
#     *c
#     ^
# SyntaxError: can't use starred expression here
